# %%
import pandas as pd

# %%
df = pd.read_csv("/data/prod/get_it_done_311_requests_datasd.csv")
df.head()
# Out:
#    service_request_id  parent_case_number status_description  \
# 0              178209                   0                New
# 1              178208                   0                New
# 2              178207                   0                New
# 3              178206                   0                New
# 4              178205              129078          Duplicate
#
#   mobile_web_status  duplicate_verified  override_duplicate  \
# 0               New                   0                   0
# 1               New                   0                   0
# 2               New                   0                   1
# 3               New                   0                   0
# 4        In process                   0                   0
#
#   functional_location referral_email referred_email_update source  \
# 0           SS-000685            NaN                   NaN    Web
# 1           SS-013034            NaN                   NaN    Web
# ...

# %%
df.dtypes
# Out:
# service_request_id           int64
# parent_case_number           int64
# status_description          object
# mobile_web_status           object
# duplicate_verified           int64
# override_duplicate           int64
# functional_location         object
# referral_email              object
# referred_email_update       object
# source                      object
# requested_datetime          object
# closed_date                 object
# updated_datetime            object
# open                         int64
# closed                       int64
# description                 object
# agency_responsible          object
# service_name                object
# service_subtype             object
# coordinates                 object
# lat                        float64
# long                       float64
# sap_notification_number     object
# sap_problem_category        object
# sap_problem_code           float64
# sap_problem_type            object
# address                     object
# ...

# %%
df['service_name'].unique()
# Out:
# array(['Tree Hazard', 'Graffiti', 'Traffic Signal', 'Street Sweeping',
#        'Curb', 'Litter/Dumping', 'Dead Animal', 'Traffic Sign', 'Other',
#        'Abandoned Vehicle', 'Pothole', 'Storm Drain', 'Street Light',
#        'Sidewalk', 'Street Flooded', 'Faded striping', nan,
#        'Damaged Guardrail', 'Parking Meter', 'Illegal discharge',
#        'Over Irrigation'], dtype=object)

# %%
street_light = df.loc[df['service_name'] == 'Street Light', :].copy()
street_light.shape
# Out:
# (6354, 28)

# %%
street_light.reset_index(inplace=True)
street_light.drop('index', 1, inplace=True)

# %%
street_light.head()
# Out:
#    service_request_id  parent_case_number status_description  \
# 0              178162                   0                New
# 1              178108                   0       Acknowledged
# 2              177990              161739          Duplicate
# 3              177984                   0       Acknowledged
# 4              177977                   0       Acknowledged
#
#   mobile_web_status  duplicate_verified  override_duplicate  \
# 0               New                   0                   0
# 1        In process                   0                   0
# 2        In process                   1                   0
# 3        In process                   0                   0
# 4        In process                   0                   0
#
#   functional_location referral_email referred_email_update  source  \
# 0                 NaN            NaN                   NaN     Web
# 1       SS-014398-007            NaN                   NaN     Web
# ...

# %%
service_name = 'Street Light'

# %%
service_name.replace(' ', '_').lower()
# Out:
# 'street_light'

# %%
import re
service_name = 'Street Light'
re.sub(r'\s|\/', '_', service_name).lower()
# Out:
# 'street_light'
