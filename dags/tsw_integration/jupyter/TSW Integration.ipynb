# %%
import os
import pandas as pd
import logging
import geopandas as gpd
from shapely.geometry import Point
import requests, json

pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


def geocode_address_google(address_line='',
                           locality='San Diego',
                           state='CA',
                           **kwargs):
    """Geocoding function using Google geocoding API."""
    address_line = str(address_line)
    locality = str(locality)
    state = str(state)
    google_token = 'AIzaSyCANr1U_qnHwX2y2WaU0YK5Wn-BCept3Ys'
    url = 'https://maps.googleapis.com/maps/api/geocode/json?'\
          + 'address={address}&'\
          + 'components=country:US|'\
          + 'administrative_area:{state}|'\
          + 'locality:{locality}&'\
          + 'key={google_token}'

    url = url.format(address=address_line,
                     state=state,
                     locality=locality,
                     google_token=google_token)

    print('Google Geocoding for: ' + address_line)
    if address_line in ['None', '', 'NaN', 'nan']:
        print('No geocode for: ' + address_line)
        return None, None
    else:
        try:
            r = requests.get(url, timeout=10)
            r.raise_for_status()
            body = json.loads(r.content)
            candidates = body['results']
            if candidates == []:
                print('No geocode for: ' + address_line)
                return None, None
            else:
                coords = body['results'][0]['geometry']['location']
                lat = coords['lat']
                lon = coords['lng']
                print('Geocode success for: ' + address_line)
                return lat, lon
        except Exception, e:
            logging.error(e)
            return None, None
        
        

        
def get_address_for_apn(apn):

    import requests

    url = "https://gissd.sandag.org/rdw/rest/services/Parcel/Parcels/MapServer/1/query"

    querystring = {
        "where":"APN IN ('{}')".format(apn),
        #"where": where_stmt,
        "objectIds":"",
        "time":"",
        "geometry":"",
        "geometryType":"esriGeometryEnvelope",
        "inSR":"",
        "spatialRel":"esriSpatialRelIntersects",
        "distance":"",
        "units":"esriSRUnit_Foot",
        "relationParam":"",
        "outFields": "*",
        #"outFields":"*",
        "returnGeometry":"true",
        "maxAllowableOffset":"",
        "geometryPrecision":"",
        "outSR":"4326",
        "gdbVersion":"",
        "returnDistinctValues":"false",
        "returnIdsOnly":"false",
        "returnCountOnly":"false",
        "returnExtentOnly":"false",
        "orderByFields":"",
        "groupByFieldsForStatistics":"",
        "outStatistics":"",
        "returnZ":"false",
        "returnM":"false",
        "multipatchOption":"",
        "resultOffset":"",
        "resultRecordCount":"",
        "f":"json"}

    headers = {
        'Cache-Control': "no-cache",
        'Postman-Token': "45d06817-feae-4fec-8dff-71c088d518d7"
        }

    print ("Get address for APN {}".format(apn))
    response = requests.request("POST", url, headers=headers, params=querystring)
    data = response.json()
    #gdf = gpd.GeoDataFrame.from_features(data['features'])

    #gdf.head()

    address = ""
    if data:
        apn_info = data['features'][0]['attributes']
        address = "{} {} {}".format(apn_info['SITUS_ADDRESS'], apn_info['SITUS_STREET'], apn_info['SITUS_SUFFIX'])

   
    return address
# Out:
# height has been deprecated.

# %%
sfv = pd.read_csv('/usr/local/airflow/poseidon/data/temp/tsw_violations_sf_temp.csv', dtype={
    'Site: Street Number': str,
    'Violation Date Formatted': str,
    'BMP Compliance Deadline': str
})
#sfv.head()

sfv.columns = ['V_NUM', 
               'STATUS', 
               'STATUS_1', 
               'V_TYPE', 
               'TYPE', 
               'V_DATE', 
               'BMP_COMP_DEADLINE',
               'SITE_ID',
               'PARCEL_APN',
               'ADDRESS_NUM',
               'ADDRESS_STREET',
               'ADDRESS_CITY',
               'ADDRESS_STATE',
               'VIOLATOR']

sfv.head()
# Out:
#         V_NUM      STATUS                 STATUS_1         V_TYPE                             TYPE     V_DATE BMP_COMP_DEADLINE      SITE_ID  PARCEL_APN ADDRESS_NUM                ADDRESS_STREET ADDRESS_CITY ADDRESS_STATE                   VIOLATOR
# 0  VI-0007250  Unresolved  Initial Review Complete  BMP Violation  Notice of Deficient Maintenance  9/12/2018         9/26/2018  Site-138069  6461104000        7847                     Airway Rd    San Diego            CA        Copart Auto Storage
# 1  VI-0007930  Unresolved  Initial Review Complete  BMP Violation  Notice of Deficient Maintenance  9/18/2018         10/2/2018  Site-138723  6461001400        2241                     Cactus Rd    San Diego            CA            ADESA San Diego
# 2  VI-0004596  Unresolved          Review Complete  BMP Violation  Structural Maintenance Citation        NaN               NaN  Site-138747  2673607700         NaN  End of Lower Scarborough Ct.    San Diego            CA  Black Mountain Ranch, LLC
# 3  VI-0007259  Unresolved  Initial Review Complete  BMP Violation  Notice of Deficient Maintenance  9/27/2018        10/11/2018  Site-138769  4416501300        3245             Sports Arena Blvd    San Diego            CA        SunBelt Investments
# 4  VI-0007260  Unresolved  Initial Review Complete  BMP Violation  Structural Maintenance Citation  9/27/2018        10/11/2018  Site-138769  4416501300        3245             Sports Arena Blvd    San Diego            CA        SunBelt Investments

# %%
sfv.loc[sfv.PARCEL_APN.isnull(), "PARCEL_APN"] = 0
sfv['PARCEL_APN'] = sfv.PARCEL_APN.astype(int)
sfv['SRC'] = 'TSW_SF'
sfv['LON'] = ''
sfv['LAT'] = ''
sfv['STATUS'] = sfv['STATUS']
sfv['TYPE'] = sfv['V_TYPE'] + ': ' + sfv['TYPE']
sfv['UUID'] = (sfv['SRC'] + '_' + sfv['V_NUM'].str.replace('-', '_')).str.lower()
sfv['ADDRESS'] = (sfv['ADDRESS_NUM'] + ' ' + sfv['ADDRESS_STREET']).astype(str)
sfv['ISSUE_DATE'] = sfv.V_DATE
sfv['COMPLY_BY'] = sfv.BMP_COMP_DEADLINE
sfv['ADDITIONAL_1'] = sfv['STATUS_1']
sfv['ADDITIONAL_2'] = ''

sfv = sfv[['UUID',
           'SRC',
           'TYPE',
           'STATUS',
           'ISSUE_DATE',
           'COMPLY_BY',
           'PARCEL_APN',
           'LON',
           'LAT',
           'ADDRESS',
           'VIOLATOR',
           'ADDITIONAL_1',
           'ADDITIONAL_2']]

sfv.head()
# Out:
#                 UUID     SRC                                            TYPE      STATUS ISSUE_DATE   COMPLY_BY  PARCEL_APN LON LAT                 ADDRESS                   VIOLATOR             ADDITIONAL_1 ADDITIONAL_2
# 0  tsw_sf_vi_0007250  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved  9/12/2018   9/26/2018  6461104000                  7847 Airway Rd        Copart Auto Storage  Initial Review Complete
# 1  tsw_sf_vi_0007930  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved  9/18/2018   10/2/2018  6461001400                  2241 Cactus Rd            ADESA San Diego  Initial Review Complete
# 2  tsw_sf_vi_0004596  TSW_SF  BMP Violation: Structural Maintenance Citation  Unresolved        NaN         NaN  2673607700                             nan  Black Mountain Ranch, LLC          Review Complete
# 3  tsw_sf_vi_0007259  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved  9/27/2018  10/11/2018  4416501300          3245 Sports Arena Blvd        SunBelt Investments  Initial Review Complete
# 4  tsw_sf_vi_0007260  TSW_SF  BMP Violation: Structural Maintenance Citation  Unresolved  9/27/2018  10/11/2018  4416501300          3245 Sports Arena Blvd        SunBelt Investments  Initial Review Complete

# %% [markdown]
# # VPM

# %%
vpm = pd.read_csv('/usr/local/airflow/poseidon/data/temp/tsw_violations_vpm_temp.csv')
vpm.head()
# Out:
#    sw_bmp_report_id  project_id                                     project_name bmpr_state  is_nov report_date reinspection_date  permit_number  sw_inspection_type_id          title  section_id    section_title            location_street location_city location_state  location_zip                                           comments
# 0              3266         523  Task SS16002 Tierrasanta Rec Pool Center Repair  submitted       1  2018-06-18        2018-06-21            NaN                      1        Routine           1  Major Buildings  11238 Claremont Mesa Blvd     San Diego             CA         92124  Inspected by Construction Storm Water 6/15/201...
# 1              2194         435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-29        2018-04-02      1837674.0                      5  Re-Inspection          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  City Tracking Permit # 523718\r\nâ€¢Miscellane...
# 2              1974         435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-21        2018-03-26      1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  For your information: \r\n\r\nWe&#39;re expect...
# 3              1804         435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-15        2018-04-16      1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  Issues observed on site:\r\n\r\nâ€¢\tAll sedim...
# 4              1805         435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-15        2018-04-16      1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  Issues observed on site:\r\n\r\nâ€¢\tAll sedim...

# %%
vpm['SRC'] = 'PW_VPM'
vpm['sw_bmp_report_id'] = vpm['sw_bmp_report_id'].astype(str)
vpm['project_id'] = vpm['project_id'].astype(str)
vpm['permit_number'] = vpm.permit_number.astype(str)
vpm['UUID'] = (vpm['SRC'] + '_' + vpm['sw_bmp_report_id'] + '_' + vpm['project_id']).str.lower()
vpm['LON'] = ''
vpm['LAT'] = ''
vpm['STATUS'] = vpm['bmpr_state']
vpm['TYPE'] = vpm.title
vpm['PARCEL_APN'] = ''
vpm['ISSUE_DATE'] = vpm['report_date']
vpm['COMPLY_BY'] = vpm['reinspection_date']
vpm['ADDRESS'] = vpm.location_street.astype(str)
vpm['CITY'] = vpm.location_city
vpm['STATE'] = vpm.location_state
vpm['ZIP'] = vpm.location_zip
vpm['VIOLATOR'] = vpm.project_name
vpm['ADDITIONAL_1'] = vpm.comments
vpm['ADDITIONAL_2'] = ''
vpm.head()
# Out:
#   sw_bmp_report_id project_id                                     project_name bmpr_state  is_nov report_date reinspection_date permit_number  sw_inspection_type_id          title  section_id    section_title            location_street location_city location_state  location_zip                                           comments     SRC             UUID LON LAT     STATUS           TYPE PARCEL_APN  ISSUE_DATE   COMPLY_BY                    ADDRESS       CITY STATE    ZIP                                         VIOLATOR                                       ADDITIONAL_1 ADDITIONAL_2
# 0             3266        523  Task SS16002 Tierrasanta Rec Pool Center Repair  submitted       1  2018-06-18        2018-06-21           nan                      1        Routine           1  Major Buildings  11238 Claremont Mesa Blvd     San Diego             CA         92124  Inspected by Construction Storm Water 6/15/201...  PW_VPM  pw_vpm_3266_523          submitted        Routine             2018-06-18  2018-06-21  11238 Claremont Mesa Blvd  San Diego    CA  92124  Task SS16002 Tierrasanta Rec Pool Center Repair  Inspected by Construction Storm Water 6/15/201...
# 1             2194        435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-29        2018-04-02     1837674.0                      5  Re-Inspection          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  City Tracking Permit # 523718\r\nâ€¢Miscellane...  PW_VPM  pw_vpm_2194_435          submitted  Re-Inspection             2018-03-29  2018-04-02     1551 Shelter Island Dr  San Diego    CA  92106             OTC - 11000284 - Kona Kai Expansion   City Tracking Permit # 523718\r\nâ€¢Miscellane...
# 2             1974        435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-21        2018-03-26     1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  For your information: \r\n\r\nWe&#39;re expect...  PW_VPM  pw_vpm_1974_435          submitted        Routine             2018-03-21  2018-03-26     1551 Shelter Island Dr  San Diego    CA  92106             OTC - 11000284 - Kona Kai Expansion   For your information: \r\n\r\nWe&#39;re expect...
# 3             1804        435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-15        2018-04-16     1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  Issues observed on site:\r\n\r\nâ€¢\tAll sedim...  PW_VPM  pw_vpm_1804_435          submitted        Routine             2018-03-15  2018-04-16     1551 Shelter Island Dr  San Diego    CA  92106             OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...
# 4             1805        435             OTC - 11000284 - Kona Kai Expansion   submitted       1  2018-03-15        2018-04-16     1837674.0                      1        Routine          10       District 2     1551 Shelter Island Dr     San Diego             CA         92106  Issues observed on site:\r\n\r\nâ€¢\tAll sedim...  PW_VPM  pw_vpm_1805_435          submitted        Routine             2018-03-15  2018-04-16     1551 Shelter Island Dr  San Diego    CA  92106             OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...

# %%
vpm = vpm[['UUID',
   'SRC',
   'TYPE',
   'STATUS',
   'ISSUE_DATE',
   'COMPLY_BY',
   'PARCEL_APN',
   'LON',
   'LAT',
   'ADDRESS',
   'VIOLATOR',
   'ADDITIONAL_1',
   'ADDITIONAL_2']]

vpm.head()
# Out:
#               UUID     SRC           TYPE     STATUS  ISSUE_DATE   COMPLY_BY PARCEL_APN LON LAT                    ADDRESS                                         VIOLATOR                                       ADDITIONAL_1 ADDITIONAL_2
# 0  pw_vpm_3266_523  PW_VPM        Routine  submitted  2018-06-18  2018-06-21                     11238 Claremont Mesa Blvd  Task SS16002 Tierrasanta Rec Pool Center Repair  Inspected by Construction Storm Water 6/15/201...
# 1  pw_vpm_2194_435  PW_VPM  Re-Inspection  submitted  2018-03-29  2018-04-02                        1551 Shelter Island Dr             OTC - 11000284 - Kona Kai Expansion   City Tracking Permit # 523718\r\nâ€¢Miscellane...
# 2  pw_vpm_1974_435  PW_VPM        Routine  submitted  2018-03-21  2018-03-26                        1551 Shelter Island Dr             OTC - 11000284 - Kona Kai Expansion   For your information: \r\n\r\nWe&#39;re expect...
# 3  pw_vpm_1804_435  PW_VPM        Routine  submitted  2018-03-15  2018-04-16                        1551 Shelter Island Dr             OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...
# 4  pw_vpm_1805_435  PW_VPM        Routine  submitted  2018-03-15  2018-04-16                        1551 Shelter Island Dr             OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...

# %% [markdown]
# # PTS

# %%
ptsv = pd.read_csv('/usr/local/airflow/poseidon/data/temp/tsw_violations_pts_temp.csv')
ptsv.head()
# Out:
#    INSP_ID  ASSESSOR_PARCEL_10   LATITUDE   LONGITUDE           STREET_ADDRESS  INSP_TYPE_ID                   INSP_TYPE_NM  INSP_RESULT_ID INSP_RESULT_NM     PERFORMED_END_DT                      PROJ_TITLE SCOPE LOCATION_NOTE CONSTRUCTION_NOTE
# 0  3677918        4.250131e+09  32.805272 -117.211903      3655 PAUL JONES AV            133         Storm Water Const BMPs               4           Fail  2018-11-13T07:14:24        Jones Residence Addition   NaN           NaN               NaN
# 1  3677909        4.163812e+09  32.802811 -117.246608        1344 MISSOURI ST            133         Storm Water Const BMPs               4           Fail  2018-11-13T07:07:54   Callahan Addition and Remodel   NaN           NaN               NaN
# 2  3677833        3.502310e+09  32.847275 -117.264779       7778 LUDINGTON PL            206  Storm Water Const BMPs-Status               4           Fail  2018-11-13T16:00:00                  Conboy Studio    NaN          ASBS               NaN
# 3  3677828        3.442303e+09  32.864544 -117.241784      8680 ROBIN HOOD LN            133         Storm Water Const BMPs               4           Fail  2018-11-13T16:00:00              Verna Pool and Spa   NaN           NaN               NaN
# 4  3677813        4.440601e+09  32.758948 -117.171225  875 HOTEL CIRCLE SOUTH            205  Storm Water Const BMPs-Status               4           Fail  2018-11-13T16:00:00  Legacy Internatn'l (build out)   NaN           NaN               NaN

# %%
ptsv.loc[ptsv.ASSESSOR_PARCEL_10.isnull(), "ASSESSOR_PARCEL_10"] = 0
ptsv['PARCEL_APN'] = ptsv.ASSESSOR_PARCEL_10.astype(int)
ptsv['LON'] = ptsv.LONGITUDE.astype(str)
ptsv['LAT'] = ptsv.LATITUDE.astype(str)
ptsv['SRC'] = 'DSD_PTS'
ptsv['TYPE'] = ptsv.INSP_TYPE_NM
ptsv['STATUS'] = ptsv.INSP_RESULT_NM
ptsv['UUID'] = (ptsv['SRC'] + '_' + ptsv['INSP_ID'].astype(str).str.replace('-', '_')).str.lower()
ptsv['ADDRESS'] = ptsv['STREET_ADDRESS'].astype(str)
ptsv['ISSUE_DATE'] = ptsv['PERFORMED_END_DT']
ptsv['VIOLATOR'] = ptsv['PROJ_TITLE']
ptsv['ADDITIONAL_1'] = ptsv['SCOPE']
ptsv['ADDITIONAL_2'] = ptsv['CONSTRUCTION_NOTE']
ptsv['COMPLY_BY'] = ''


ptsv = ptsv[['UUID',
           'SRC',
           'TYPE',
           'STATUS',
           'ISSUE_DATE',
           'COMPLY_BY',
           'PARCEL_APN',
           'LON',
           'LAT',
           'ADDRESS',
           'VIOLATOR',
           'ADDITIONAL_1',
           'ADDITIONAL_2']]
ptsv.head()
# Out:
#               UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY  PARCEL_APN          LON        LAT                  ADDRESS                        VIOLATOR ADDITIONAL_1 ADDITIONAL_2
# 0  dsd_pts_3677918  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:14:24            4250130600  -117.211903  32.805272      3655 PAUL JONES AV         Jones Residence Addition          NaN          NaN
# 1  dsd_pts_3677909  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:07:54            4163811500  -117.246608  32.802811        1344 MISSOURI ST    Callahan Addition and Remodel          NaN          NaN
# 2  dsd_pts_3677833  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            3502310200  -117.264779  32.847275       7778 LUDINGTON PL                   Conboy Studio           NaN          NaN
# 3  dsd_pts_3677828  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T16:00:00            3442303200  -117.241784  32.864544      8680 ROBIN HOOD LN               Verna Pool and Spa          NaN          NaN
# 4  dsd_pts_3677813  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            4440601000  -117.171225  32.758948  875 HOTEL CIRCLE SOUTH   Legacy Internatn'l (build out)          NaN          NaN

# %%
vs = pd.concat([ptsv, sfv, vpm])
print(vs.shape)
vs.head()
# Out:
# (3943, 13)
#               UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY  PARCEL_APN          LON        LAT                  ADDRESS                        VIOLATOR ADDITIONAL_1 ADDITIONAL_2
# 0  dsd_pts_3677918  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:14:24            4250130600  -117.211903  32.805272      3655 PAUL JONES AV         Jones Residence Addition          NaN          NaN
# 1  dsd_pts_3677909  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:07:54            4163811500  -117.246608  32.802811        1344 MISSOURI ST    Callahan Addition and Remodel          NaN          NaN
# 2  dsd_pts_3677833  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            3502310200  -117.264779  32.847275       7778 LUDINGTON PL                   Conboy Studio           NaN          NaN
# 3  dsd_pts_3677828  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T16:00:00            3442303200  -117.241784  32.864544      8680 ROBIN HOOD LN               Verna Pool and Spa          NaN          NaN
# 4  dsd_pts_3677813  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            4440601000  -117.171225  32.758948  875 HOTEL CIRCLE SOUTH   Legacy Internatn'l (build out)          NaN          NaN

# %%
# Try to geocode missing Addresses:

def get_geocode(row):
    
    
    
    if (row['LON'] == '') or (row['LAT'] == ''):
        address = row['ADDRESS']
        if (address == '') or (address == 'nan'):
            address = get_address_for_apn(row['PARCEL_APN'])
            
        print(address)
        
        gres = geocode_address_google(address, 'San Diego', 'CA')
        print(gres)
        if gres[0] == None:
            address = get_address_for_apn(row['PARCEL_APN'])
            print("Attempt geocode at new address {}".format(address))
            if len(address) > 0:
                gres = geocode_address_google(address, 'San Diego', 'CA')
                print(gres)
        
        row['LON'] = gres[1]
        row['LAT'] = gres[0]
        row['ADDRESS'] = address
        
    return row

# %%
vs = vs.apply(get_geocode, axis=1)
# Out:
# 7847 Airway Rd
# Google Geocoding for: 7847 Airway Rd
# Geocode success for: 7847 Airway Rd
# (32.559634, -116.9725946)
# 2241 Cactus Rd
# Google Geocoding for: 2241 Cactus Rd
# No geocode for: 2241 Cactus Rd
# (None, None)
# Get address for APN 6461001400
# Attempt geocode at new address 2241 CACTUS RD
# Google Geocoding for: 2241 CACTUS RD
# No geocode for: 2241 CACTUS RD
# (None, None)
# Get address for APN 2673607700
# 0 PASEO MONTENERO None
# Google Geocoding for: 0 PASEO MONTENERO None
# Geocode success for: 0 PASEO MONTENERO None
# (33.0168043, -117.1402095)
# 3245 Sports Arena Blvd
# Google Geocoding for: 3245 Sports Arena Blvd
# Geocode success for: 3245 Sports Arena Blvd
# (32.7514122, -117.2102048)
# 3245 Sports Arena Blvd
# Google Geocoding for: 3245 Sports Arena Blvd
# Geocode success for: 3245 Sports Arena Blvd
# (32.7514122, -117.2102048)
# 8583 Aero Dr
# Google Geocoding for: 8583 Aero Dr
# Geocode success for: 8583 Aero Dr
# (32.808881, -117.141733)
# 2930 Barnard St
# Google Geocoding for: 2930 Barnard St
# Geocode success for: 2930 Barnard St
# (32.752544, -117.2242776)
# 10155 Pacific Heights Blvd
# Google Geocoding for: 10155 Pacific Heights Blvd
# Geocode success for: 10155 Pacific Heights Blvd
# (32.9033057, -117.1940842)
# 12770 El Camino Real
# Google Geocoding for: 12770 El Camino Real
# Geocode success for: 12770 El Camino Real
# (35.440323, -120.63222)
# 12770 El Camino Real
# Google Geocoding for: 12770 El Camino Real
# Geocode success for: 12770 El Camino Real
# (35.440323, -120.63222)
# 9898 Genesee Ave
# Google Geocoding for: 9898 Genesee Ave
# Geocode success for: 9898 Genesee Ave
# (32.8843387, -117.2244128)
# 9888 Genesee Ave
# Google Geocoding for: 9888 Genesee Ave
# Geocode success for: 9888 Genesee Ave
# (32.8851544, -117.2255383)
# Get address for APN 3052906500
# 0 PLUMERIA WAY
# Google Geocoding for: 0 PLUMERIA WAY
# No geocode for: 0 PLUMERIA WAY
# (None, None)
# Get address for APN 3052906500
# Attempt geocode at new address 0 PLUMERIA WAY
# Google Geocoding for: 0 PLUMERIA WAY
# No geocode for: 0 PLUMERIA WAY
# (None, None)
# Get address for APN 3050214400
# 0 AZUL LUNA WAY
# Google Geocoding for: 0 AZUL LUNA WAY
# Geocode success for: 0 AZUL LUNA WAY
# (32.9661236, -117.1715811)
# 11238 Claremont Mesa Blvd
# Google Geocoding for: 11238 Claremont Mesa Blvd
# Geocode success for: 11238 Claremont Mesa Blvd
# (32.8303889, -117.0873837)
# 1551 Shelter Island Dr
# Google Geocoding for: 1551 Shelter Island Dr
# Geocode success for: 1551 Shelter Island Dr
# (32.709513, -117.2320611)
# 1551 Shelter Island Dr
# Google Geocoding for: 1551 Shelter Island Dr
# Geocode success for: 1551 Shelter Island Dr
# (32.709513, -117.2320611)
# 1551 Shelter Island Dr
# Google Geocoding for: 1551 Shelter Island Dr
# Geocode success for: 1551 Shelter Island Dr
# (32.709513, -117.2320611)
# 1551 Shelter Island Dr
# Google Geocoding for: 1551 Shelter Island Dr
# Geocode success for: 1551 Shelter Island Dr
# (32.709513, -117.2320611)
# 901-957 Block Pacific Highway
# Google Geocoding for: 901-957 Block Pacific Highway
# Geocode success for: 901-957 Block Pacific Highway
# (33.7902494, -118.1814714)
# 9913 1/3 ERMA Rd
# Google Geocoding for: 9913 1/3 ERMA Rd
# Geocode success for: 9913 1/3 ERMA Rd
# (32.9187291, -117.1131738)
# 5260 Roswell Street
# Google Geocoding for: 5260 Roswell Street
# Geocode success for: 5260 Roswell Street
# (32.7131977, -117.0822813)
# 5260 Roswell Street
# Google Geocoding for: 5260 Roswell Street
# Geocode success for: 5260 Roswell Street
# (32.7131977, -117.0822813)
# 8025 Birmingham Dr
# Google Geocoding for: 8025 Birmingham Dr
# No geocode for: 8025 Birmingham Dr
# (None, None)
# Get address for APN
# IndexErrorTraceback (most recent call last)
# <ipython-input-51-fbe8464b0a5b> in <module>()
# ----> 1 vs = vs.apply(get_geocode, axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4150                     if reduce is None:
#    4151                         reduce = True
# -> 4152                     return self._apply_standard(f, axis, reduce=reduce)
#    4153             else:
#    4154                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4246             try:
#    4247                 for i, v in enumerate(series_gen):
# -> 4248                     results[i] = func(v)
#    4249                     keys.append(v.name)
#    4250             except Exception as e:
#
# <ipython-input-50-1fb488f442e8> in get_geocode(row)
#      15         print(gres)
#      16         if gres[0] == None:
# ---> 17             address = get_address_for_apn(row['PARCEL_APN'])
#      18             print("Attempt geocode at new address {}".format(address))
#      19             if len(address) > 0:
#
# <ipython-input-41-d6e7f110d39e> in get_address_for_apn(apn)
#     107     address = ""
#     108     if data:
# --> 109         apn_info = data['features'][0]['attributes']
#     110         address = "{} {} {}".format(apn_info['SITUS_ADDRESS'], apn_info['SITUS_STREET'], apn_info['SITUS_SUFFIX'])
#     111
#
# IndexError: ('list index out of range', u'occurred at index 9')

# %%
# REmove non geocodes
print(vs[((vs.LON.astype(str) == '') | (vs.LAT.astype(str) == ''))].shape)
#vs = vs[(vs.LON.astype(str) != '') & (vs.LAT.astype(str) != '')]
vs[((vs.LON.astype(str) == '') | (vs.LAT.astype(str) == ''))].head(1000)
# Out:
# (39, 13)
#                  UUID     SRC                                            TYPE      STATUS  ISSUE_DATE   COMPLY_BY  PARCEL_APN LON LAT                        ADDRESS                                           VIOLATOR                                       ADDITIONAL_1 ADDITIONAL_2
# 0   tsw_sf_vi_0007250  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/12/2018   9/26/2018  6461104000                         7847 Airway Rd                                Copart Auto Storage                            Initial Review Complete
# 1   tsw_sf_vi_0007930  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/18/2018   10/2/2018  6461001400                         2241 Cactus Rd                                    ADESA San Diego                            Initial Review Complete
# 2   tsw_sf_vi_0004596  TSW_SF  BMP Violation: Structural Maintenance Citation  Unresolved         NaN         NaN  2673607700                                    nan                          Black Mountain Ranch, LLC                                    Review Complete
# 3   tsw_sf_vi_0007259  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/27/2018  10/11/2018  4416501300                 3245 Sports Arena Blvd                                SunBelt Investments                            Initial Review Complete
# 4   tsw_sf_vi_0007260  TSW_SF  BMP Violation: Structural Maintenance Citation  Unresolved   9/27/2018  10/11/2018  4416501300                 3245 Sports Arena Blvd                                SunBelt Investments                            Initial Review Complete
# 5   tsw_sf_vi_0007138  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/19/2018   10/3/2018  4210501500                           8583 Aero Dr                                   Olympus Property                            Initial Review Complete
# 6   tsw_sf_vi_0007297  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/17/2018   10/1/2018  4497200200                        2930 Barnard St          Dylan Point Loma, attn: Community Manager                            Initial Review Complete
# 7   tsw_sf_vi_0006939  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/13/2018   9/27/2018  3413923300             10155 Pacific Heights Blvd                                                NaN                            Initial Review Complete
# 8   tsw_sf_vi_0004247  TSW_SF  BMP Violation: Notice of Deficient Maintenance    Resolved   5/28/2018   6/12/2018  3040706000                   12770 El Camino Real                                      Kilroy Realty                                    Review Complete
# 9   tsw_sf_vi_0006454  TSW_SF       BMP Violation: Structural Maintenance NOV    Resolved   5/28/2018   6/12/2018  3040706000                   12770 El Camino Real                                      Kilroy Realty                                    Review Complete
# 10  tsw_sf_vi_0006273  TSW_SF       BMP Violation: Structural Maintenance NOV    Resolved   6/12/2018   6/26/2018  3431603300                       9898 Genesee Ave                 Scripps Memorial Hospital La Jolla                                    Review Complete
# 11  tsw_sf_vi_0007060  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/11/2018   9/25/2018  3431601600                       9888 Genesee Ave                                     Scripps Health                            Initial Review Complete
# 12  tsw_sf_vi_0007645  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved         NaN         NaN  3052906500                                    nan                                                NaN                            Initial Review Complete
# 13  tsw_sf_vi_0007535  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/12/2018   9/26/2018  3050214400                                    nan                              JD Richardson Company                            Initial Review Complete
# 0     pw_vpm_3266_523  PW_VPM                                         Routine   submitted  2018-06-18  2018-06-21                          11238 Claremont Mesa Blvd    Task SS16002 Tierrasanta Rec Pool Center Repair  Inspected by Construction Storm Water 6/15/201...
# 1     pw_vpm_2194_435  PW_VPM                                   Re-Inspection   submitted  2018-03-29  2018-04-02                             1551 Shelter Island Dr               OTC - 11000284 - Kona Kai Expansion   City Tracking Permit # 523718\r\nâ€¢Miscellane...
# 2     pw_vpm_1974_435  PW_VPM                                         Routine   submitted  2018-03-21  2018-03-26                             1551 Shelter Island Dr               OTC - 11000284 - Kona Kai Expansion   For your information: \r\n\r\nWe&#39;re expect...
# 3     pw_vpm_1804_435  PW_VPM                                         Routine   submitted  2018-03-15  2018-04-16                             1551 Shelter Island Dr               OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...
# 4     pw_vpm_1805_435  PW_VPM                                         Routine   submitted  2018-03-15  2018-04-16                             1551 Shelter Island Dr               OTC - 11000284 - Kona Kai Expansion   Issues observed on site:\r\n\r\nâ€¢\tAll sedim...
# 5     pw_vpm_1696_166  PW_VPM                                         Routine   submitted  2018-03-09  2018-03-12                      901-957 Block Pacific Highway  24004099 - Pacific Highway and West Broadway (PI)  Inspection preformed on 3/8/18.  Missing perim...
# 6     pw_vpm_1514_455  PW_VPM                                         Routine   submitted  2018-03-02  2018-03-05                                   9913 1/3 ERMA Rd                       OTC - 11003294 - ATT A014WM1  Waste water from saw cutting operation was obs...
# 7     pw_vpm_1363_206  PW_VPM                                        Pre-Rain   submitted  2018-02-23  2018-02-26                                5260 Roswell Street                     24006724 - 5260 Roswell Street  graded slope is missing erosion control blanke...
# 8     pw_vpm_1244_206  PW_VPM                                         Routine   submitted  2018-02-13  2018-02-16                                5260 Roswell Street                     24006724 - 5260 Roswell Street  provide bmp at end of the day, slope need BMP ...
# 9      pw_vpm_1145_89  PW_VPM                                         Routine   submitted  2018-02-06  2018-02-09                                8025 Birmingham Dr        24007242 - Sharp Birmingham Garage Expansion  â€¢\tInlet protection was missing from constru...
# 10     pw_vpm_812_166  PW_VPM                                            Rain   submitted  2018-01-10  2018-01-16                      901-957 Block Pacific Highway  24004099 - Pacific Highway and West Broadway (PI)  Inspection 1-9-18\r\nAll concrete & other mate...
# 11     pw_vpm_830_215  PW_VPM                                            Rain   submitted  2018-01-10  2018-01-16                            7155 Camino Maquiladora             23431125 - Continental Commerce Center   Inspected 1/09/18:During periods of inactivit...
# 12     pw_vpm_792_206  PW_VPM                                        Pre-Rain   submitted  2018-01-09  2018-01-12                                5260 Roswell Street                     24006724 - 5260 Roswell Street                                                NaN
# 13     pw_vpm_726_166  PW_VPM                                         Routine   submitted  2018-01-05  2018-01-08                      901-957 Block Pacific Highway  24004099 - Pacific Highway and West Broadway (PI)  Inspection preformed on 1-4-18\r\nInstall peri...
# 14     pw_vpm_665_166  PW_VPM                                         Routine   submitted  2017-12-27  2018-01-02                      901-957 Block Pacific Highway  24004099 - Pacific Highway and West Broadway (PI)  Chemicals need to be stored properly covered a...
# 15     pw_vpm_631_206  PW_VPM                                       Post-Rain   submitted  2017-12-21  2017-12-26                                5260 Roswell Street                     24006724 - 5260 Roswell Street                                                NaN
# 16      pw_vpm_432_91  PW_VPM                                         Routine   submitted  2017-11-30  2017-12-04                               3777 Townsgate Drive  Carmel Valley Rec. Center Voluntary ADA Improv...                                                NaN
# 17     pw_vpm_299_149  PW_VPM                                   Re-Inspection   submitted  2017-11-15  2017-11-16                                       340 14th St.                        24005413 - Alexan San Diego  Storm drain inlets were maintained, but the tr...
# 18     pw_vpm_269_149  PW_VPM                                         Routine   submitted  2017-11-09  2017-11-13                                       340 14th St.                        24005413 - Alexan San Diego  please maintain the following BMP&#39;s: \r\n1...
# 19     pw_vpm_256_149  PW_VPM                                         Routine   submitted  2017-11-08  2017-11-13                                       340 14th St.                        24005413 - Alexan San Diego  please maintain the following BMP&#39;s:\r\n1-...
# 20     pw_vpm_225_206  PW_VPM                                         Routine   submitted  2017-11-07  2018-02-07                                5260 Roswell Street                     24006724 - 5260 Roswell Street  grading is active in the rear side of the prop...
# 21     pw_vpm_203_279  PW_VPM                                   Re-Inspection   submitted  2017-11-03  2017-11-06                                   2916 Worden St.                 OTC - 11000284 - Loma Palisades ROW  Entrance still inadequate\r\nFiber rolls inade...
# 22     pw_vpm_171_279  PW_VPM                                   Re-Inspection   submitted  2017-11-01  2017-11-02                                   2916 Worden St.                 OTC - 11000284 - Loma Palisades ROW  Needs to improve street sweeping\r\nLoose sedi...
# 23     pw_vpm_163_279  PW_VPM                                         Routine   submitted  2017-10-31  2017-10-31                                   2916 Worden St.                 OTC - 11000284 - Loma Palisades ROW  Tracking sediment out of site\r\nSediment in t...
# 24       pw_vpm_91_89  PW_VPM                                         Routine   submitted  2017-10-20  2017-10-27                                8025 Birmingham Dr        24007242 - Sharp Birmingham Garage Expansion  See attached pdf file for corrective action it...

# %%
vs.ADDITIONAL_1 = vs.ADDITIONAL_1.astype(str)
vs.ADDITIONAL_2 = vs.ADDITIONAL_2.astype(str)
vs.ADDITIONAL_1 = vs.ADDITIONAL_1.apply(lambda x: ''.join(e for e in x if e.isalnum()))
vs.ADDITIONAL_2 = vs.ADDITIONAL_2.apply(lambda x: ''.join(e for e in x if e.isalnum()))

# %%
vs['LON'] = pd.to_numeric(vs.LON, downcast='float')
vs['LAT'] = pd.to_numeric(vs.LAT, downcast='float')
#vs['COORD'] = vs.COORD.apply(Point)
vs['COORD'] = list(zip(vs.LON, vs.LAT))
vs['COORD'] = vs.COORD.apply(Point)
vs = gpd.GeoDataFrame(vs, geometry='COORD')
vs.head()
# Out:
#               UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY  PARCEL_APN         LON        LAT                  ADDRESS                        VIOLATOR ADDITIONAL_1 ADDITIONAL_2                                         COORD
# 0  dsd_pts_3677918  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:14:24            4250130600 -117.211906  32.805271      3655 PAUL JONES AV         Jones Residence Addition          nan          nan  POINT (-117.2119064331055 32.80527114868164)
# 1  dsd_pts_3677909  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:07:54            4163811500 -117.246605  32.802811        1344 MISSOURI ST    Callahan Addition and Remodel          nan          nan  POINT (-117.2466049194336 32.80281066894531)
# 2  dsd_pts_3677833  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            3502310200 -117.264778  32.847275       7778 LUDINGTON PL                   Conboy Studio           nan          nan   POINT (-117.264778137207 32.84727478027344)
# 3  dsd_pts_3677828  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T16:00:00            3442303200 -117.241783  32.864544      8680 ROBIN HOOD LN               Verna Pool and Spa          nan          nan  POINT (-117.2417831420898 32.86454391479492)
# 4  dsd_pts_3677813  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            4440601000 -117.171227  32.758949  875 HOTEL CIRCLE SOUTH   Legacy Internatn'l (build out)          nan          nan  POINT (-117.1712265014648 32.75894927978516)

# %%
vs.groupby('SRC').count()["UUID"]

# %%
t = vs.loc[vs.STATUS.astype(str) == 'Fail']
t.loc[0,]
# Out:
# UUID                                         dsd_pts_3677918
# SRC                                                  DSD_PTS
# TYPE                                  Storm Water Const BMPs
# STATUS                                                  Fail
# ISSUE_DATE                               2018-11-13T07:14:24
# COMPLY_BY
# PARCEL_APN                                        4250130600
# LON                                                 -117.212
# LAT                                                  32.8053
# ADDRESS                                  3655 PAUL JONES AV
# VIOLATOR                            Jones Residence Addition
# ADDITIONAL_1                                             nan
# ADDITIONAL_2                                             nan
# COORD           POINT (-117.2119064331055 32.80527114868164)
# Name: 0, dtype: object

# %%
print(2+3)
# Out:
# 5

# %%
os.remove('/usr/local/airflow/poseidon/data/temp/tsw_violations_merged.geojson')
vs.to_file('/usr/local/airflow/poseidon/data/temp/tsw_violations_merged.geojson', driver='GeoJSON')

# %%
# Reconstruct and Write

vs.to_csv('/usr/local/airflow/poseidon/data/temp/tsw_violations_merged.csv')
vs.head()
# Out:
#               UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY  PARCEL_APN          LON        LAT                  ADDRESS                        VIOLATOR ADDITIONAL_1 ADDITIONAL_2
# 0  dsd_pts_3677918  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:14:24            4250130600  -117.211903  32.805272      3655 PAUL JONES AV         Jones Residence Addition          NaN          NaN
# 1  dsd_pts_3677909  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T07:07:54            4163811500  -117.246608  32.802811        1344 MISSOURI ST    Callahan Addition and Remodel          NaN          NaN
# 2  dsd_pts_3677833  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            3502310200  -117.264779  32.847275       7778 LUDINGTON PL                   Conboy Studio           NaN          NaN
# 3  dsd_pts_3677828  DSD_PTS         Storm Water Const BMPs   Fail  2018-11-13T16:00:00            3442303200  -117.241784  32.864544      8680 ROBIN HOOD LN               Verna Pool and Spa          NaN          NaN
# 4  dsd_pts_3677813  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-11-13T16:00:00            4440601000  -117.171225  32.758948  875 HOTEL CIRCLE SOUTH   Legacy Internatn'l (build out)          NaN          NaN

# %%
df = pd.read_csv('/usr/local/airflow/poseidon/data/prod/stormwater_violations_merged.csv')
df[((df['LON'].astype(str) == '') | (df['LAT'].astype(str) == ''))]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, UUID, SRC, TYPE, STATUS, ISSUE_DATE, COMPLY_BY, PARCEL_APN, LON, LAT, ADDRESS, VIOLATOR, ADDITIONAL_1, ADDITIONAL_2, COORD]
# Index: []

# %%
print(vs[((vs.LON.astype(str) == '') | (vs.LAT.astype(str) == ''))].shape)
#vs = vs[(vs.LON.astype(str) != '') & (vs.LAT.astype(str) != '')]
vs[((vs.LON.astype(str) == '') | (vs.LAT.astype(str) == ''))].head(1000)
# Out:
# (0, 14)
# Empty GeoDataFrame
# Columns: [UUID, SRC, TYPE, STATUS, ISSUE_DATE, COMPLY_BY, PARCEL_APN, LON, LAT, ADDRESS, VIOLATOR, ADDITIONAL_1, ADDITIONAL_2, COORD]
# Index: []

# %%
where_stmt = "APN IN ("
for i in parcel_prim.PARCEL_APN:
    where_stmt = where_stmt + "'" + str(i) + "', "

where_stmt = where_stmt + ")"
where_stmt = where_stmt.replace(', )', ")")
where_stmt
# Out:
# "APN IN ('6461104000', '2673607700', '4416501300', '4416501300', '4210501500', '4497200200', '3413923300', '3040706000', '3040706000', '3431603300', '3431601600')"

# %%
def get_address_for_apn(apn):

    apn = '6461104000'

    import requests

    url = "https://gissd.sandag.org/rdw/rest/services/Parcel/Parcels/MapServer/1/query"

    querystring = {
        "where":"APN IN ('{}')".format(apn),
        #"where": where_stmt,
        "objectIds":"",
        "time":"",
        "geometry":"",
        "geometryType":"esriGeometryEnvelope",
        "inSR":"",
        "spatialRel":"esriSpatialRelIntersects",
        "distance":"",
        "units":"esriSRUnit_Foot",
        "relationParam":"",
        "outFields": "*",
        #"outFields":"*",
        "returnGeometry":"true",
        "maxAllowableOffset":"",
        "geometryPrecision":"",
        "outSR":"4326",
        "gdbVersion":"",
        "returnDistinctValues":"false",
        "returnIdsOnly":"false",
        "returnCountOnly":"false",
        "returnExtentOnly":"false",
        "orderByFields":"",
        "groupByFieldsForStatistics":"",
        "outStatistics":"",
        "returnZ":"false",
        "returnM":"false",
        "multipatchOption":"",
        "resultOffset":"",
        "resultRecordCount":"",
        "f":"json"}

    headers = {
        'Cache-Control': "no-cache",
        'Postman-Token': "45d06817-feae-4fec-8dff-71c088d518d7"
        }

    response = requests.request("POST", url, headers=headers, params=querystring)
    data = response.json()
    #gdf = gpd.GeoDataFrame.from_features(data['features'])

    #gdf.head()

    apn_info = data['features'][0]['attributes']

    address = "{} {} {} {}".format(apn_info['SITUS_ADDRESS'], apn_info['SITUS_STREET'], apn_info['SITUS_SUFFIX'], apn_info['SITUS_ZIP'])

    print(address)
    return address
# Out:
# '7847 AIRWAY RD 92154-8305'

# %%
def remoteGeoJSONToGDF(url, display = False):
    """Import remote GeoJSON to a GeoDataFrame
    Keyword arguments:
    url -- URL to GeoJSON resource on web
    display -- Displays geometries upon loading (default: False)
    """
    r = requests.get(url)
    data = r.json()
    gdf = gpd.GeoDataFrame.from_features(data['features'])
    if display:
        gdf.plot()
return gdf
# Out:
# {u'geometry': {u'rings': [[[-117.22532022565962, 32.883570890024], [-117.22590078922704, 32.88340652253302], [-117.22631008722587, 32.884435749534106], [-117.22572951844542, 32.8846001189375], [-117.22532022565962, 32.883570890024]]]}, u'attributes': {u'APN': u'3431601600'}}
# {u'geometry': {u'rings': [[[-116.97112397409542, 32.56047461978179], [-116.971163317663, 32.55698925628499], [-116.97118370594045, 32.55517535448164], [-116.97119247164807, 32.55439548055537], [-116.97119812378011, 32.55389260295056], [-116.97120205232673, 32.553543161628234], [-116.971202114527, 32.553537665046285], [-116.9733726679221, 32.55354184228616], [-116.97329225871542, 32.56048767305919], [-116.97112397409542, 32.56047461978179]]]}, u'attributes': {u'APN': u'6461104000'}}
# {u'geometry': {u'rings': [[[-117.14174411011962, 33.01505306740294], [-117.1416919219961, 33.015013114778384], [-117.14163561373451, 33.01497735029007], [-117.14164605075725, 33.01494265876375], [-117.14165224253945, 33.01490696429254], [-117.14165409931121, 33.01487078438319], [-117.14164079072522, 33.01355836666915], [-117.14170339345687, 33.0135688568788], [-117.1417647096854, 33.01358527231746], [-117.14182417993878, 33.01360746320458], [-117.14188126158832, 33.01363522706226], [-117.14193096441117, 33.01366395457011], [-117.14197693665797, 33.01369833760127], [-117.14201853802079, 33.013737897264036], [-117.14205518907002, 33.01378208256586], [-117.14208637932468, 33.01383027808765], [-117.14211167436252, 33.01388181255541], [-117.14213072187071, 33.01393596818982], [-117.14214325655287, 33.0139919907036], [-117.14214910382418, 33.014049099807295], [-117.14214766563825, 33.01408865552478], [-117.14212623525619, 33.01434397206576], [-117.14211506842479, 33.01442501829102], [-117.14209778029104, 33.014504982715515], [-117.14207447066153, 33.01458340369437], [-117.14204527410573, 33.01465982849324], [-117.14201035917911, 33.01473381590198], [-117.14196992745002, 33.01480493878181], [-117.14192421233598, 33.01487278653123], [-117.14187347775622, 33.0149369674565], [-117.14181801660794, 33.014997111032926], [-117.14175814907549, 33.015052870043945], [-117.1417565968889, 33.01505396170015], [-117.14175488148751, 33.01505477311531], [-117.14175305297297, 33.01505528059046], [-117.1417511647506, 33.01505546930382], [-117.1417492719696, 33.01505533374363], [-117.14174742991233, 33.015054877869204], [-117.14174569237967, 33.01505411499523], [-117.14174411011962, 33.01505306740294]]]}, u'attributes': {u'APN': u'2673607700'}}
# {u'geometry': {u'rings': [[[-117.22272648542399, 32.884878005714725], [-117.22258230319758, 32.884650722663025], [-117.22258929792662, 32.884647562457914], [-117.22258627055992, 32.88464208084965], [-117.22258420189497, 32.884636170384056], [-117.22258315012157, 32.884629997317475], [-117.2225831448252, 32.884623735293026], [-117.22258418615483, 32.88461756045612], [-117.22258624481877, 32.88461164649966], [-117.22258926290853, 32.884606159778194], [-117.22259315552785, 32.884601254628535], [-117.22259781318063, 32.88459706902836], [-117.22260310485107, 32.884593720715046], [-117.22263488554854, 32.88457433186905], [-117.22261110446048, 32.88454658093168], [-117.22255545279013, 32.884481614933364], [-117.22246168045385, 32.88437214650534], [-117.2224557048032, 32.88437538706995], [-117.22244943947754, 32.884378024370484], [-117.22244505531818, 32.88437946130947], [-117.22244282267026, 32.8843800828689], [-117.22243828760014, 32.88438112864265], [-117.22242786100446, 32.88438243983881], [-117.22241735309456, 32.88438230960002], [-117.22240696219973, 32.88438074038445], [-117.22239688444073, 32.88437776180992], [-117.22334872931049, 32.88313169570186], [-117.22356200950549, 32.883667969509084], [-117.22344157507989, 32.88370206490353], [-117.22369750953315, 32.88434566376077], [-117.22405265236617, 32.88424512570849], [-117.22419150300217, 32.88459428389169], [-117.22488325965031, 32.88439844794838], [-117.22474442125052, 32.884049291799386], [-117.22448850363793, 32.88340569698086], [-117.22414477208834, 32.88254124661375], [-117.22414517353693, 32.882541317659225], [-117.22434743684857, 32.88257392606646], [-117.22455071534753, 32.88259945266685], [-117.22475476115696, 32.882617866333376], [-117.22495932546441, 32.8826291446125], [-117.22516415882515, 32.88263327375155], [-117.22536901146638, 32.88263024871548], [-117.2255736335918, 32.88262007319299], [-117.22577777568614, 32.882602759592075], [-117.22598118881956, 32.882578329024845], [-117.22618362495106, 32.88254681128182], [-117.22638483723101, 32.88250824479558], [-117.22658458030213, 32.882462676593924], [-117.22678261059869, 32.88241016224248], [-117.22687185638844, 32.88263458684867], [-117.22691826762053, 32.88275129498583], [-117.22702937551475, 32.88271965977291], [-117.22712727703858, 32.88296444902787], [-117.22701567694662, 32.88299622633176], [-117.227176077132, 32.88339955344353], [-117.22754140020557, 32.883296108238014], [-117.22751561036932, 32.883436567238626], [-117.22749501138216, 32.883577880819836], [-117.22743279798357, 32.88406646671656], [-117.22739827051781, 32.88432111774736], [-117.22733321040639, 32.88454102351767], [-117.22730729850255, 32.884628605630965], [-117.2273005255855, 32.88465149742854], [-117.22727044353347, 32.88470568007058], [-117.22717056684832, 32.88488557518873], [-117.2270782679396, 32.885408659899866], [-117.22705935808189, 32.885423182861], [-117.2270763645459, 32.88532681407995], [-117.2270051645362, 32.88514667899708], [-117.22713897948852, 32.88467630720511], [-117.2272729552269, 32.884205362972594], [-117.22727516622719, 32.88419759119328], [-117.22727173384145, 32.88419856039797], [-117.22640118327334, 32.88444430467922], [-117.22639525612, 32.88444597795624], [-117.2265500359018, 32.884835789023604], [-117.22661165718648, 32.88507148740417], [-117.22662999647265, 32.88512851533917], [-117.22665949404401, 32.88537124614329], [-117.22676848729259, 32.88564658039281], [-117.22603876586227, 32.886207020392945], [-117.2259784113041, 32.88624947599773], [-117.22591516182196, 32.88628748460308], [-117.22584934447327, 32.886320849669886], [-117.22578129959366, 32.88634939867039], [-117.22571137903711, 32.88637298398026], [-117.2256291961128, 32.886394456411345], [-117.22555184584112, 32.886408736396355], [-117.22547370099885, 32.88641770111206], [-117.22539512639891, 32.8864213087074], [-117.22531648886047, 32.886419542340604], [-117.2252381554966, 32.88641241025781], [-117.22516049200027, 32.88639994575458], [-117.22508386093 ...
# {u'geometry': {u'rings': [[[-117.22337166065691, 32.75292069366366], [-117.2233779045263, 32.75290881197798], [-117.22338598566093, 32.752896888312534], [-117.22339397521172, 32.752884918643964], [-117.22340187320917, 32.752872905720686], [-117.22340967965319, 32.75286084954263], [-117.22341739132189, 32.752848752883835], [-117.22342501140686, 32.752836610222], [-117.22343253674697, 32.75282442982768], [-117.22343997053382, 32.752812206178746], [-117.22344730629307, 32.75279994207475], [-117.22345455055986, 32.752787640212716], [-117.22346170005149, 32.752775297869974], [-117.22346875476798, 32.75276291504662], [-117.22347571473978, 32.75275049449088], [-117.22348257671452, 32.75273803622851], [-117.22348934394459, 32.75272554023376], [-117.2234960164604, 32.75271300925507], [-117.22350259097931, 32.75270044056968], [-117.22350906750125, 32.7526878341777], [-117.22351544608716, 32.75267519557575], [-117.22352173318082, 32.75266251921591], [-117.2235279190861, 32.75264981067174], [-117.22353400705538, 32.752637069917576], [-117.22353999702793, 32.752624291456904], [-117.22354588909485, 32.75261148353455], [-117.22355168322589, 32.752598643402294], [-117.22355737942104, 32.75258577106016], [-117.22356297445842, 32.75257286928205], [-117.22369224983443, 32.752203545934734], [-117.22369495345407, 32.7521953697057], [-117.22369949783103, 32.75218217112549], [-117.22370424448773, 32.75216902866792], [-117.22370919661557, 32.75215593681075], [-117.22371434780105, 32.75214290385016], [-117.22379118819336, 32.75203235615785], [-117.22386480646973, 32.75192458238005], [-117.22457035931824, 32.751044981097664], [-117.2249243079035, 32.750603711548365], [-117.22551479523837, 32.75103751761309], [-117.22570726969667, 32.75117891659947], [-117.22573347049722, 32.7511952005943], [-117.22573071393388, 32.751827384774536], [-117.22573054735892, 32.75184112600378], [-117.22573057920455, 32.751854868412515], [-117.22573081594496, 32.75186860920087], [-117.22573124128836, 32.75188234574923], [-117.22573187149631, 32.751896077929], [-117.2257327000035, 32.75190980029493], [-117.22573373009267, 32.7519235155697], [-117.22573495519855, 32.75193721830813], [-117.22573637857334, 32.751950908484524], [-117.2257380034088, 32.75196458057646], [-117.22573982323065, 32.75197823738378], [-117.22574184448285, 32.75199187335843], [-117.22574406063035, 32.75200548580349], [-117.22574647492567, 32.75201907469328], [-117.22574908411646, 32.75203264005352], [-117.2257518913943, 32.752046176361866], [-117.22575489347655, 32.75205968089569], [-117.22575809036326, 32.75207315365508], [-117.22576148530683, 32.75208659461425], [-117.22576507174192, 32.752099998328], [-117.2257688561427, 32.75211336199667], [-117.2257728287828, 32.75212668844563], [-117.22577699610609, 32.75213997212685], [-117.22577980729739, 32.752148574788514], [-117.22589223086884, 32.75248341884401], [-117.22588376942385, 32.75248534652445], [-117.2258680764533, 32.75248894753661], [-117.22585239029047, 32.752492575978266], [-117.2258367141573, 32.752496229075376], [-117.22582104480139, 32.752499906853735], [-117.22580537900093, 32.75250361208717], [-117.22578973295658, 32.752507339150775], [-117.22577408724574, 32.75251109644347], [-117.2257584547863, 32.75251487561771], [-117.22574282588226, 32.752518682247135], [-117.22572720700776, 32.7525225135321], [-117.22571160141506, 32.75252636944675], [-117.22569600263, 32.75253025279095], [-117.22568041062218, 32.75253416081634], [-117.22566482864381, 32.75253809349724], [-117.22564925672539, 32.752542053581934], [-117.22563369158412, 32.75254603834785], [-117.2256181365027, 32.7525500505176], [-117.22560259138989, 32.75255408184623], [-117.22558705636736, 32.75255814332703], [-117.22557152812195, 32.752562229488994], [-117.22555600990594, 32.75256634030652], [-117.22554050171931, 32.75257047577962], [-117.22552500359252, 32.752574638656476], [-117.22550951549515, 32.7525788261889], [-117.22549403742711, 32.7525830383768], [-117.22547856613608, 32.7525 ...
# {u'geometry': {u'rings': [[[-117.23727613540184, 32.950484524921436], [-117.2358399000067, 32.9500636822343], [-117.23584241532386, 32.95006029248801], [-117.23594024604839, 32.94992440934755], [-117.23603359600314, 32.94978540983507], [-117.23612236599782, 32.9496434416465], [-117.23612280046677, 32.94964272287771], [-117.23612312131597, 32.9496421919148], [-117.23612354059468, 32.94964149937816], [-117.23612385774702, 32.9496410021142], [-117.23612461993886, 32.94963978393576], [-117.23612496264396, 32.94963923974305], [-117.23612538216156, 32.94963856850559], [-117.23612572486661, 32.94963802431289], [-117.23612614441502, 32.94963735582367], [-117.23612648712013, 32.94963681163099], [-117.2361269034089, 32.94963614316779], [-117.23612724605233, 32.9496355934785], [-117.23612766560072, 32.94963492498933], [-117.23612800827493, 32.94963437804833], [-117.23612842456373, 32.94963370958513], [-117.23612876723789, 32.94963316264414], [-117.23612918352666, 32.94963249418094], [-117.23612952620088, 32.949631947239965], [-117.2361299424588, 32.94963127602845], [-117.23613028513302, 32.94963072908741], [-117.23613070468136, 32.94963006059821], [-117.23613104409587, 32.94962951368323], [-117.23613146361345, 32.949628842445705], [-117.23613180305878, 32.94962829827902], [-117.23613221934754, 32.949627629815794], [-117.23613256199086, 32.949627080126504], [-117.23613297501993, 32.94962641168928], [-117.23613331769411, 32.949625864748285], [-117.2361337339828, 32.94962519628506], [-117.23613407662614, 32.949624646595765], [-117.23613449288398, 32.94962397538424], [-117.23613483232934, 32.949623431217546], [-117.236135248618, 32.9496227627543], [-117.23613559126126, 32.94962221306502], [-117.23613600429033, 32.94962154462777], [-117.23613634696444, 32.949620997686736], [-117.23613675999351, 32.94962032924955], [-117.23613710263676, 32.94961977956021], [-117.23613751889455, 32.949619108348706], [-117.23613785830904, 32.949618561433674], [-117.23613827456683, 32.94961789022217], [-117.23613861395049, 32.949617340558866], [-117.23613902701032, 32.94961667486986], [-117.23613936639399, 32.949616125206596], [-117.23613978268253, 32.94961545674331], [-117.2361401253258, 32.94961490705401], [-117.23614053506432, 32.949614235894515], [-117.23614087447879, 32.949613688979404], [-117.2361412907365, 32.94961301776794], [-117.23614162689137, 32.94961247087885], [-117.23614204317991, 32.9496118024156], [-117.23614238256353, 32.949611252752305], [-117.2361427955616, 32.94961058156676], [-117.23614313494527, 32.94961003190347], [-117.23614354797415, 32.94960936346617], [-117.23614388409813, 32.94960881382886], [-117.23614430038666, 32.9496081453656], [-117.23614463973942, 32.949607592954024], [-117.23614505273744, 32.94960692176843], [-117.23614539215187, 32.949606374853396], [-117.23614580189036, 32.949605703693834], [-117.23614614127389, 32.949605154030515], [-117.23614655104315, 32.94960448561925], [-117.23614689042667, 32.94960393595589], [-117.23614730665355, 32.949603261996074], [-117.23614764280826, 32.949602715107005], [-117.23614805580634, 32.94960204392146], [-117.23614839193023, 32.949601494284124], [-117.23614880495907, 32.94960082584684], [-117.23614914108299, 32.949600276209466], [-117.23614955405016, 32.94959960227565], [-117.23614989020489, 32.94959905538657], [-117.23615030320286, 32.94959838420099], [-117.23615063932675, 32.949597834563654], [-117.23615105232479, 32.949597163378066], [-117.23615138844863, 32.949596613740745], [-117.236151798187, 32.949595942581155], [-117.23615213757044, 32.94959539291781], [-117.23615254733966, 32.9495947245065], [-117.23615288343268, 32.949594172120854], [-117.23615329643063, 32.94959350093528], [-117.23615363255448, 32.94959295129797], [-117.236154042262, 32.949592277390096], [-117.23615437838579, 32.949591727752754], [-117.23615478815498, 32.949591059341415], [-117.23615512424799, 32.949590506955765], [-117.23615553398628, 32.94958983579618], [-117.23615587011011, 32.94958928615882], [-117.23615627 ...
# {u'geometry': {u'rings': [[[-117.1403141988968, 32.80949767811598], [-117.14031357185219, 32.80893796580596], [-117.14029675749883, 32.80852322854592], [-117.14029646325496, 32.8082610857319], [-117.14064205330234, 32.80825536300564], [-117.14112788095787, 32.80824730721878], [-117.14143140676296, 32.808242273424476], [-117.14163903759258, 32.80823882954008], [-117.14185051962424, 32.808235321069134], [-117.14196567466712, 32.80823340420605], [-117.14205621423875, 32.8082319090218], [-117.14226382305229, 32.808228464245445], [-117.14247724203672, 32.80822492283701], [-117.14257279200827, 32.80822333677201], [-117.14260274671037, 32.8095018180834], [-117.14221520346328, 32.80950823217356], [-117.14220845502324, 32.80950329920212], [-117.14220248632199, 32.809497446830306], [-117.14199091413981, 32.80950094897524], [-117.14198522104756, 32.80950699484958], [-117.14197870776725, 32.80951214665269], [-117.14073967432996, 32.809532643871236], [-117.14036397346639, 32.80953885677091], [-117.14035601175463, 32.8095389104739], [-117.14034816160137, 32.809537581251675], [-117.1403406613811, 32.809534909466855], [-117.14033373884246, 32.80953097624976], [-117.14032760419238, 32.80952590103483], [-117.14032244371315, 32.80951983793397], [-117.14031841410572, 32.80951297105679], [-117.14031563773153, 32.809505508920076], [-117.1403141988968, 32.80949767811598]]]}, u'attributes': {u'APN': u'4210501500'}}
# {u'geometry': {u'rings': [[[-117.20723618221878, 32.75212594982091], [-117.2076990799901, 32.75158936597383], [-117.20805467172333, 32.751174328956175], [-117.20819690873765, 32.751008310005204], [-117.20846850132125, 32.751171114925086], [-117.2084877092924, 32.751182627715274], [-117.20871745903261, 32.75132034699913], [-117.20874258499893, 32.751335287905114], [-117.20808534577, 32.752089526429494], [-117.2080757082571, 32.752100584381985], [-117.20806606757915, 32.75211165060383], [-117.20805642686884, 32.75212271407661], [-117.2080467925711, 32.75213376925332], [-117.20803717432328, 32.75214480506484], [-117.20802757537776, 32.752155821486106], [-117.20802182049682, 32.75216918553581], [-117.20801416236219, 32.752181308285856], [-117.20800685717884, 32.752193584960985], [-117.20799991792632, 32.75220601271204], [-117.20799334776743, 32.75221858326892], [-117.20798714658275, 32.75223128563846], [-117.20798132084714, 32.752244117022016], [-117.20797587366373, 32.75225706365279], [-117.20797080825503, 32.75227012275739], [-117.2079661277539, 32.752283283317375], [-117.2079618385757, 32.75229653703739], [-117.20795794391296, 32.752309878395636], [-117.207954262542, 32.752323990434064], [-117.20793122015145, 32.752407661360536], [-117.20792923005159, 32.752414886199546], [-117.20792603126536, 32.75241355326137], [-117.20783576919878, 32.75237592852746], [-117.20723618221878, 32.75212594982091]]]}, u'attributes': {u'APN': u'4416501300'}}
# {u'geometry': {u'rings': [[[-117.19356840111723, 32.90287321888803], [-117.1941538789774, 32.902302282984934], [-117.19415495551155, 32.90230331919941], [-117.19415602875827, 32.902304352690514], [-117.19415710526293, 32.90230538615667], [-117.19415817525191, 32.90230641967259], [-117.19415924849869, 32.90230745316366], [-117.19416032177509, 32.902308489402984], [-117.1941613917936, 32.90230952566723], [-117.19416246181211, 32.902310561931394], [-117.19416353183068, 32.902311598195595], [-117.1941645985914, 32.90231263448468], [-117.19416566538165, 32.902313673522016], [-117.19416673220147, 32.902314715307696], [-117.19416779896225, 32.90231575159668], [-117.19416886575259, 32.90231679063403], [-117.19416992928505, 32.90231782969623], [-117.19417099284708, 32.902318871506694], [-117.19417205640912, 32.90231991331724], [-117.19417311997115, 32.902320955127735], [-117.19417418027537, 32.902321996963124], [-117.19417524057963, 32.902323038798436], [-117.19417630091338, 32.90232408338207], [-117.19417736124718, 32.90232512796571], [-117.1941784183231, 32.90232617257416], [-117.19417947865699, 32.902327217157755], [-117.1941805292172, 32.90232826181603], [-117.1941815895806, 32.90232930914791], [-117.19418264342828, 32.90233035652961], [-117.19418370053384, 32.902331403886365], [-117.19418475438161, 32.902332451267974], [-117.19418580819983, 32.90233349590128], [-117.19418685884877, 32.902334548804404], [-117.19418790946817, 32.90233559895916], [-117.19418896008763, 32.902336649113956], [-117.19419001070713, 32.902337699268784], [-117.19419105806875, 32.902338749448376], [-117.19419210871779, 32.90233980235146], [-117.19419315607949, 32.90234085253104], [-117.19419420347073, 32.90234190545897], [-117.19419524763354, 32.90234296116007], [-117.19419629502485, 32.90234401408802], [-117.19419733918775, 32.902345069789106], [-117.19419838332121, 32.90234612274188], [-117.19419942422633, 32.90234717846781], [-117.19420046841881, 32.90234823691714], [-117.19420150932396, 32.902349292643066], [-117.19420255022915, 32.90235034836902], [-117.19420358790596, 32.90235140686811], [-117.1942046288407, 32.90235246534233], [-117.19420566651758, 32.902353523841406], [-117.19420670422397, 32.90235458508878], [-117.19420774190093, 32.90235564358782], [-117.19420877634951, 32.90235670486007], [-117.19420981082762, 32.902357768880606], [-117.19421084524677, 32.902358827404505], [-117.19421187969542, 32.90235988867673], [-117.19421291091572, 32.90236095272211], [-117.19421394542347, 32.902362019490894], [-117.19421497658482, 32.902363078039656], [-117.19421600457686, 32.90236414485825], [-117.19421703579727, 32.902365208903575], [-117.19421806375986, 32.90236627297382], [-117.19421909500981, 32.90236733976748], [-117.1942201197441, 32.90236840661087], [-117.19422114773619, 32.90236947342941], [-117.1942221724705, 32.90237054027278], [-117.19422319723435, 32.902371609864474], [-117.19422422196867, 32.90237267670779], [-117.19422524347469, 32.902373746324365], [-117.19422626823862, 32.902374815916005], [-117.19422728977419, 32.90237588828083], [-117.19422831128031, 32.902376957897374], [-117.19422932955803, 32.90237803028706], [-117.19423034780627, 32.90237909992845], [-117.19423136934188, 32.90238017229325], [-117.19423238110402, 32.90238124473265], [-117.19423340263968, 32.902382317097505], [-117.19423441771872, 32.90238339500862], [-117.1942354359966, 32.902384467398235], [-117.19423644778827, 32.90238554258595], [-117.19423746286733, 32.902386620497076], [-117.19423847465903, 32.902387695684745], [-117.19423948970866, 32.902388770847594], [-117.19424049827207, 32.90238984880843], [-117.19424151009335, 32.90239092674441], [-117.19424252191466, 32.902392004680394], [-117.19424353047818, 32.90239308264123], [-117.19424453907116, 32.90239416335032], [-117.19424554440629, 32.902395244084346], [-117.19424655299939, 32.902396324793436], [-117.19424755833455, 32.90239740552751], [-117.19424856366982, 32.90239848626147], [-117.19424956248933, 32.90239956704519 ...

# %%
## Create A DF where only PARCEL_APN exists, but not lat/lon

parcel_prim = vs[vs.PARCEL_APN.notnull() & (vs.PARCEL_APN != 0) & (
    (vs.LON == '') | (vs.LAT == '') | (vs.LON.isnull()) | (vs.LAT.isnull()))]

parcel_prim.sort_values(by='LON', na_position='first').head()
# Out:
#                  UUID     SRC                                            TYPE      STATUS  ISSUE_DATE   COMPLY_BY  PARCEL_APN LON LAT                        ADDRESS                                           VIOLATOR                                       ADDITIONAL_1 ADDITIONAL_2
# 0   tsw_sf_vi_0007250  TSW_SF  BMP Violation: Notice of Deficient Maintenance  Unresolved   9/12/2018   9/26/2018  6461104000                         7847 Airway Rd                                Copart Auto Storage                            Initial Review Complete
# 7     pw_vpm_1363_206  PW_VPM                                        Pre-Rain   submitted  2018-02-23  2018-02-26                                5260 Roswell Street                     24006724 - 5260 Roswell Street  graded slope is missing erosion control blanke...
# 8     pw_vpm_1244_206  PW_VPM                                         Routine   submitted  2018-02-13  2018-02-16                                5260 Roswell Street                     24006724 - 5260 Roswell Street  provide bmp at end of the day, slope need BMP ...
# 9      pw_vpm_1145_89  PW_VPM                                         Routine   submitted  2018-02-06  2018-02-09                                8025 Birmingham Dr        24007242 - Sharp Birmingham Garage Expansion  â€¢\tInlet protection was missing from constru...
# 10     pw_vpm_812_166  PW_VPM                                            Rain   submitted  2018-01-10  2018-01-16                      901-957 Block Pacific Highway  24004099 - Pacific Highway and West Broadway (PI)  Inspection 1-9-18\r\nAll concrete & other mate...

# %%
## Create A DF where only LAT_LN EXISTS but NOT PARCEL_APN

ll_prim = vs[vs.PARCEL_APN.isnull() | (vs.PARCEL_APN == 0) & (
    (vs.LON != '') & (vs.LAT != '') & (vs.LON.notnull()) & (vs.LAT.notnull()))]

ll_prim.sort_values(by='PARCEL_APN', na_position='first').head()
# Out:
#                UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY PARCEL_APN          LON        LAT            ADDRESS                    VIOLATOR ADDITIONAL_1 ADDITIONAL_2
# 3   dsd_pts_3667942  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-26T14:02:51                    0  -117.012265  32.859868  8996 HIGHTAIL DR   TALUS Phased Dev 2016 (63)          NaN          NaN
# 5   dsd_pts_3667932  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-26T14:03:19                    0  -117.012282  32.859989  9002 HIGHTAIL DR   TALUS Phased Dev 2016 (63)          NaN          NaN
# 6   dsd_pts_3667931  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-26T14:03:06                    0  -117.012277  32.859712  8990 HIGHTAIL DR   TALUS Phased Dev 2016 (63)          NaN          NaN
# 15  dsd_pts_3667007  DSD_PTS         Storm Water Const BMPs   Fail  2018-10-26T16:00:00                    0  -117.012335   32.86042  9020 HIGHTAIL DR   TALUS Phased Dev 2016 (63)          NaN          NaN
# 16  dsd_pts_3667006  DSD_PTS         Storm Water Const BMPs   Fail  2018-10-26T16:00:00                    0  -117.012284  32.860143  9008 HIGHTAIL DR   TALUS Phased Dev 2016 (63)          NaN          NaN

# %%
## Create A DF where everything is legit

legit = vs[vs.PARCEL_APN.notnull() & (vs.PARCEL_APN != 0) & (
    (vs.LON != '') & (vs.LAT != '') & (vs.LON.notnull()) & (vs.LAT.notnull()))]

legit.sort_values(by=['PARCEL_APN', 'LON', 'LAT'], na_position='first').head()
# Out:
#                UUID      SRC                           TYPE STATUS           ISSUE_DATE COMPLY_BY  PARCEL_APN          LON        LAT                   ADDRESS                        VIOLATOR ADDITIONAL_1 ADDITIONAL_2
# 90  dsd_pts_3662311  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-22T14:38:04            2673812700  -117.150941  33.011859  15441 ARTESIAN RIDGE RD   Artesian Phased Dev. 2016 (36)          NaN          NaN
# 4   dsd_pts_3667936  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-29T16:00:00            3050103800  -117.193119  32.968231          6124 ARTISAN WY      PHR - ALMERIA 17A 2013 (80)          NaN          NaN
# 2   dsd_pts_3667943  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-29T16:00:00            3050103800  -117.193495  32.968063          6116 ARTISAN WY      PHR - ALMERIA 17A 2013 (80)          NaN          NaN
# 37  dsd_pts_3664888  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-25T16:00:00            3050103800  -117.193943  32.967829        6090 SEAFARING WY      PHR - ALMERIA 17A 2013 (80)          NaN          NaN
# 14  dsd_pts_3667020  DSD_PTS  Storm Water Const BMPs-Status   Fail  2018-10-25T16:00:00            3050103800  -117.194028  32.968202        6098 SEAFARING WY      PHR - ALMERIA 17A 2013 (80)          NaN          NaN

# %%
# Run some stats
all_row_count = parcel_prim.shape[0] + ll_prim.shape[0] + legit.shape[0]

print("""
Parcels Only Count: {} \n
LonLat Only Count: {} \n
Legit Count: {} \n

Total: {}
""").format(parcel_prim.shape[0], ll_prim.shape[0], legit.shape[0], all_row_count)

assert(all_row_count == vs.shape[0])
# Out:
# Parcels Only Count: 39
#
# LonLat Only Count: 14
#
# Legit Count: 86
#
#
# Total: 139
